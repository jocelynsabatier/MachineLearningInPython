# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
link = "https://raw.githubusercontent.com/murpi/wilddata/master/pokemon.csv"
pokemon = pd.read_csv(link)

# %%
pokemon
# Out:
#        #            Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1       Bulbasaur    Grass  Poison  45      49       49       65
# 1      2         Ivysaur    Grass  Poison  60      62       63       80
# 2      3        Venusaur    Grass  Poison  80      82       83      100
# 3      4   Mega Venusaur    Grass  Poison  80     100      123      122
# 4      5      Charmander     Fire     NaN  39      52       43       60
# ..   ...             ...      ...     ...  ..     ...      ...      ...
# 795  796         Diancie     Rock   Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock   Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic   Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic    Dark  80     160       60      170
# 799  800       Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
pokemon = pokemon[['Name', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Legendary']]
pokemon
# Out:
#                Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Legendary
# 0         Bulbasaur  45      49       49       65       65     45      False
# 1           Ivysaur  60      62       63       80       80     60      False
# 2          Venusaur  80      82       83      100      100     80      False
# 3     Mega Venusaur  80     100      123      122      120     80      False
# 4        Charmander  39      52       43       60       50     65      False
# ..              ...  ..     ...      ...      ...      ...    ...        ...
# 795         Diancie  50     100      150      100      150     50       True
# 796    Mega Diancie  50     160      110      160      110    110       True
# 797  Hoopa Confined  80     110       60      150      130     70       True
# 798   Hoopa Unbound  80     160       60      170      130     80       True
# 799       Volcanion  80     110      120      130       90     70       True
#
# [800 rows x 8 columns]

# %%
non_legendary_pokemon = pokemon[~(pokemon['Legendary'] == True)]

# %%
non_legendary_pokemon
# Out:
#                      Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0               Bulbasaur  45      49       49       65       65     45
# 1                 Ivysaur  60      62       63       80       80     60
# 2                Venusaur  80      82       83      100      100     80
# 3           Mega Venusaur  80     100      123      122      120     80
# 4              Charmander  39      52       43       60       50     65
# ..                    ...  ..     ...      ...      ...      ...    ...
# 787  Gourgeist Super Size  85     100      122       58       75     54
# 788              Bergmite  55      69       85       32       35     28
# 789               Avalugg  95     117      184       44       46     28
# 790                Noibat  40      30       35       45       40     55
# 791               Noivern  85      70       80       97       80    123
#
#      Legendary
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ...

# %%
legendary_pokemon = pokemon[(pokemon['Legendary'] == True)]

# %%
legendary_pokemon
# Out:
#                Name   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Legendary
# 156        Articuno   90      85      100       95      125     85       True
# 157          Zapdos   90      90       85      125       90    100       True
# 158         Moltres   90     100       90      125       85     90       True
# 162          Mewtwo  106     110       90      154       90    130       True
# 163   Mega Mewtwo X  106     190      100      154      100    130       True
# ..              ...  ...     ...      ...      ...      ...    ...        ...
# 795         Diancie   50     100      150      100      150     50       True
# 796    Mega Diancie   50     160      110      160      110    110       True
# 797  Hoopa Confined   80     110       60      150      130     70       True
# 798   Hoopa Unbound   80     160       60      170      130     80       True
# 799       Volcanion   80     110      120      130       90     70       True
#
# [65 rows x 8 columns]

# %%
#on cherche a trouvé les voisin de Mewtwo, Lugia, Rayquaza, Giratina, Dialga, et Palkia.

#commençons par trouver les stat de Mewtwo :

mewtwo = legendary_pokemon[(legendary_pokemon['Name'] == 'Mewtwo')]
mewtwo
# Out:
#        Name   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Legendary
# 162  Mewtwo  106     110       90      154       90    130       True

# %%
from sklearn.neighbors import NearestNeighbors

X = non_legendary_pokemon[['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']]

distanceKNN = NearestNeighbors(n_neighbors=1).fit(X)

distanceKNN.kneighbors([[106,	110,	90,	154,	90,	130]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# (array([[42.21374184]]), array([[242]]))

# %%
neighbors = distanceKNN.kneighbors([[106,	110,	90,	154,	90,	130]])

non_legendary_pokemon.iloc[neighbors[1][0][0]]


#le meilleur remplaçant pour mewtwo est Mega Houndoom
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# Name         Mega Houndoom
# HP                      75
# Attack                  90
# Defense                 90
# Sp. Atk                140
# Sp. Def                 90
# Speed                  115
# Legendary            False
# Name: 248, dtype: object

# %%
lugia = legendary_pokemon[(legendary_pokemon['Name'] == 'Lugia')]
lugia
# Out:
#       Name   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Legendary
# 269  Lugia  106      90      130       90      154    110       True

# %%
neighborsL = distanceKNN.kneighbors([[106,	90,	130,	90,	154,	110]])

non_legendary_pokemon.iloc[neighborsL[1][0][0]]
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# Name         Cresselia
# HP                 120
# Attack              70
# Defense            120
# Sp. Atk             75
# Sp. Def            130
# Speed               85
# Legendary        False
# Name: 546, dtype: object

# %%
rayqua = legendary_pokemon[(legendary_pokemon['Name'] == 'Rayquaza')]
rayqua
# Out:
#          Name   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Legendary
# 425  Rayquaza  105     150       90      150       90     95       True

# %%
neighborsR = distanceKNN.kneighbors([[105,	150,	90,	150,	90,	95	]])

non_legendary_pokemon.iloc[neighborsR[1][0][0]]
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# Name         Mega Blaziken
# HP                      80
# Attack                 160
# Defense                 80
# Sp. Atk                130
# Sp. Def                 80
# Speed                  100
# Legendary            False
# Name: 279, dtype: object

# %%
gira = legendary_pokemon[(legendary_pokemon['Name'] == 'Giratina Altered Forme')]
gira
# Out:
#                        Name   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 544  Giratina Altered Forme  150     100      120      100      120     90
#
#      Legendary
# 544       True

# %%
neighborsG = distanceKNN.kneighbors([[150,	100,	120,	100,	120,	90	]])

non_legendary_pokemon.iloc[neighborsG[1][0][0]]
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# Name         Cresselia
# HP                 120
# Attack              70
# Defense            120
# Sp. Atk             75
# Sp. Def            130
# Speed               85
# Legendary        False
# Name: 546, dtype: object

# %%
dialga = legendary_pokemon[(legendary_pokemon['Name'] == 'Dialga')]
dialga
# Out:
#        Name   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Legendary
# 540  Dialga  100     120      120      150      100     90       True

# %%
neighborsD = distanceKNN.kneighbors([[100,	120,	120,	150,	100,	90	]])

non_legendary_pokemon.iloc[neighborsD[1][0][0]]
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# Name         Mega Blastoise
# HP                       79
# Attack                  103
# Defense                 120
# Sp. Atk                 135
# Sp. Def                 115
# Speed                    78
# Legendary             False
# Name: 12, dtype: object

# %%
palkia = legendary_pokemon[(legendary_pokemon['Name'] == 'Palkia')]
palkia
# Out:
#        Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Legendary
# 541  Palkia  90     120      100      150      120    100       True

# %%
neighborsP = distanceKNN.kneighbors([[90,	120,	100,	150,	120,	100		]])

non_legendary_pokemon.iloc[neighborsP[1][0][0]]
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# Name         Mega Charizard Y
# HP                         78
# Attack                    104
# Defense                    78
# Sp. Atk                   159
# Sp. Def                   115
# Speed                     100
# Legendary               False
# Name: 8, dtype: object

# %%
# Mega Houndoom, Cresselia,  Mega Blaziken, Cresselia,  Mega Blastoise et  Mega Charizard Y pourrait remplacer les Pokémons légendaires du Champion
